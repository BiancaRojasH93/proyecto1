# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
import numpy as np

path = "/content/drive/MyDrive/colab/CORE_Proyecto_i/retail_sales_dataset.csv"
df = pd.read_csv(path)
# Out:
# Mounted at /content/drive

# %%
df.head(10)
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
# 5               6  2023-04-25     CUST006  Female   45           Beauty
# 6               7  2023-03-13     CUST007    Male   46         Clothing
# 7               8  2023-02-22     CUST008    Male   30      Electronics
# 8               9  2023-12-13     CUST009    Male   63      Electronics
# 9              10  2023-10-07     CUST010  Female   52         Clothing
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100
# 5         1              30            30
# 6         2              25            50
# 7         4              25           100
# 8         2             300           600
# 9         4              50           200

# %% [markdown]
# ### Exploración Inicial de los Datos

# %% [markdown]
# Muestra las últimas 5 filas del DataFrame.

# %%
df.tail(5)
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 995             996  2023-05-16     CUST996    Male   62         Clothing
# 996             997  2023-11-17     CUST997    Male   52           Beauty
# 997             998  2023-10-29     CUST998  Female   23           Beauty
# 998             999  2023-12-05     CUST999  Female   36      Electronics
# 999            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount
# 995         1              50            50
# 996         3              30            90
# 997         4              25           100
# 998         3              50           150
# 999         4              30           120

# %% [markdown]
# Utiliza el método info() para obtener información general sobre el DataFrame, incluyendo el número de entradas, nombres de las columnas, tipos de datos y memoria utilizada.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   object
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 70.4+ KB

# %% [markdown]
# Genera estadísticas descriptivas del DataFrame utilizando el método describe().

# %%
df.describe()
# Out:
#        Transaction ID         Age     Quantity  Price per Unit  Total Amount
# count     1000.000000  1000.00000  1000.000000     1000.000000   1000.000000
# mean       500.500000    41.39200     2.514000      179.890000    456.000000
# std        288.819436    13.68143     1.132734      189.681356    559.997632
# min          1.000000    18.00000     1.000000       25.000000     25.000000
# 25%        250.750000    29.00000     1.000000       30.000000     60.000000
# 50%        500.500000    42.00000     3.000000       50.000000    135.000000
# 75%        750.250000    53.00000     4.000000      300.000000    900.000000
# max       1000.000000    64.00000     4.000000      500.000000   2000.000000

# %% [markdown]
# ### Inspección de los Datos

# %% [markdown]
# Inspecciona los tipos de datos de cada columna utilizando el atributo dtypes.

# %%
for column in df.columns:
   print(f"{column} : {df[column].dtypes}")
# Out:
# Transaction ID : int64
# Date : object
# Customer ID : object
# Gender : object
# Age : int64
# Product Category : object
# Quantity : int64
# Price per Unit : int64
# Total Amount : int64

# %% [markdown]
# Cuenta los valores únicos en la columna Producto utilizando el método value_counts().

# %%
df.value_counts("Product Category")
# Out:
# Product Category
# Clothing       351
# Electronics    342
# Beauty         307
# Name: count, dtype: int64

# %% [markdown]
# Muestra todos los valores únicos en la columna Tienda utilizando el método unique().

# %%
df["Price per Unit"].unique()

## Dado que no existe la columna "Tienda" en el dataset, muestro los valores de la columna Price per Unit, ya que es mas concisa que otras columnas
# Out:
# array([ 50, 500,  30,  25, 300])

# %% [markdown]
# ### Filtrado de Datos

# %% [markdown]
# Filtra el DataFrame para mostrar solo las filas donde las ventas (Ventas) sean mayores a 50.

# %%
fil_ventas = df["Total Amount"] > 50
df[fil_ventas].head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
# 7               8  2023-02-22     CUST008    Male   30      Electronics
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 3         1             500           500
# 4         2              50           100
# 7         4              25           100

# %% [markdown]
# Filtra el DataFrame para mostrar solo las filas donde el precio (Precio) sea menor a 0.5.

# %%
fil_precio = df["Price per Unit"] < 50
df[fil_precio].head()

## Debido a que no hay filas con precio menor a 0.5 lo modifique a 50
# Out:
#     Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 2                3  2023-01-13     CUST003    Male   50      Electronics
# 5                6  2023-04-25     CUST006  Female   45           Beauty
# 6                7  2023-03-13     CUST007    Male   46         Clothing
# 7                8  2023-02-22     CUST008    Male   30      Electronics
# 11              12  2023-10-30     CUST012    Male   35           Beauty
#
#     Quantity  Price per Unit  Total Amount
# 2          1              30            30
# 5          1              30            30
# 6          2              25            50
# 7          4              25           100
# 11         3              25            75

# %% [markdown]
# Utilizando el método query(), filtra el DataFrame para mostrar las filas donde el producto sea Manzanas y las ventas sean mayores a 30.

# %%
fil_Beauty = df.query("`Product Category` == 'Beauty' and `Total Amount` > 30")
fil_Beauty.head()

### Producto "Manzanas" fue reemplazado por  categoría "Beauty"
# Out:
#     Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0                1  2023-11-24     CUST001    Male   34           Beauty
# 4                5  2023-05-06     CUST005    Male   30           Beauty
# 11              12  2023-10-30     CUST012    Male   35           Beauty
# 20              21  2023-01-14     CUST021  Female   50           Beauty
# 24              25  2023-12-26     CUST025  Female   64           Beauty
#
#     Quantity  Price per Unit  Total Amount
# 0          3              50           150
# 4          2              50           100
# 11         3              25            75
# 20         1             500           500
# 24         1              50            50

# %% [markdown]
# ### Slicing de Datos

# %% [markdown]
# Selecciona y muestra solo las columnas Producto y Ventas del DataFrame.

# %%
prod_ventas = df[["Product Category", "Total Amount"]]
prod_ventas.head()
# Out:
#   Product Category  Total Amount
# 0           Beauty           150
# 1         Clothing          1000
# 2      Electronics            30
# 3         Clothing           500
# 4           Beauty           100

# %% [markdown]
# Utilizando loc[], selecciona y muestra las filas de la 5 a la 10 (inclusive) y las columnas Producto y Tienda.

# %%
loc2 = df.loc[5:10, ["Product Category", "Price per Unit"]]
loc2

## Se reemplazó la columna "Tienda" (no existe) por "Price per Unit"
# Out:
#    Product Category  Price per Unit
# 5            Beauty              30
# 6          Clothing              25
# 7       Electronics              25
# 8       Electronics             300
# 9          Clothing              50
# 10         Clothing              50

# %% [markdown]
# Utilizando iloc[], selecciona y muestra las primeras 5 filas y las primeras 3 columnas del DataFrame.

# %%
iloc2 = df.iloc[:5, :3]
iloc2
# Out:
#    Transaction ID        Date Customer ID
# 0               1  2023-11-24     CUST001
# 1               2  2023-02-27     CUST002
# 2               3  2023-01-13     CUST003
# 3               4  2023-05-21     CUST004
# 4               5  2023-05-06     CUST005
