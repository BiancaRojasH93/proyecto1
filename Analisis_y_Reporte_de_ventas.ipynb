# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
import numpy as np

path = "/content/drive/MyDrive/colab/CORE_Proyecto_i/retail_sales_dataset.csv"
df = pd.read_csv(path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0                 1  2023-11-24     CUST001    Male   34           Beauty
# 1                 2  2023-02-27     CUST002  Female   26         Clothing
# 2                 3  2023-01-13     CUST003    Male   50      Electronics
# 3                 4  2023-05-21     CUST004    Male   37         Clothing
# 4                 5  2023-05-06     CUST005    Male   30           Beauty
# ..              ...         ...         ...     ...  ...              ...
# 995             996  2023-05-16     CUST996    Male   62         Clothing
# 996             997  2023-11-17     CUST997    Male   52           Beauty
# 997             998  2023-10-29     CUST998  Female   23           Beauty
# 998             999  2023-12-05     CUST999  Female   36      Electronics
# 999            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   datetime64[ns]
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
# dtypes: datetime64[ns](1), int64(5), object(3)
# memory usage: 70.4+ KB

# %% [markdown]
# # Exploración de Datos

# %% [markdown]
# Calcula el total de ventas por categoría de producto.

# %%
df.groupby('Product Category')['Total Amount'].sum()
# Out:
# Product Category
# Beauty         143515
# Clothing       155580
# Electronics    156905
# Name: Total Amount, dtype: int64

# %% [markdown]
# Calcula el promedio de ventas diarias por categoría de producto.

# %%
ventas_diarias = df.groupby(['Product Category', 'Date'])['Total Amount'].sum()
promedio_ventas = ventas_diarias.groupby('Product Category').mean()

promedio_ventas
# Out:
# Product Category
# Beauty         703.504902
# Clothing       670.603448
# Electronics    716.461187
# Name: Total Amount, dtype: float64

# %% [markdown]
# Identifica las categorías de productos con mayores y menores ventas.

# %%
df.groupby('Product Category')['Total Amount'].sum().sort_values(ascending=False)
# Out:
# Product Category
# Electronics    156905
# Clothing       155580
# Beauty         143515
# Name: Total Amount, dtype: int64

# %%
df_max = df["Product Category"].max()


df_max
# Out:
# 'Electronics'

# %%
df_min = df["Product Category"].min()
df_min
# Out:
# 'Beauty'

# %% [markdown]
# #Manipulación de Datos

# %% [markdown]
# Filtra los datos para mostrar solo las ventas de una categoría de producto específica.

# %%
df_1 = df[df['Product Category'] == 'Electronics']
df_1
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 2                 3  2023-01-13     CUST003    Male   50      Electronics
# 7                 8  2023-02-22     CUST008    Male   30      Electronics
# 8                 9  2023-12-13     CUST009    Male   63      Electronics
# 12               13  2023-08-05     CUST013    Male   22      Electronics
# 14               15  2023-01-16     CUST015  Female   42      Electronics
# ..              ...         ...         ...     ...  ...              ...
# 988             989  2023-12-28     CUST989  Female   44      Electronics
# 991             992  2023-08-21     CUST992  Female   57      Electronics
# 992             993  2023-02-06     CUST993  Female   48      Electronics
# 998             999  2023-12-05     CUST999  Female   36      Electronics
# 999            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount
# ...

# %% [markdown]
# Realiza operaciones de suma, resta, multiplicación y división en los datos para obtener estadísticas adicionales.

# %%
#Podemos obtener el monto total de ventas por género

df.groupby('Gender')['Total Amount'].sum()
# Out:
# Gender
# Female    232840
# Male      223160
# Name: Total Amount, dtype: int64

# %%
#Prodemos ver qué categoria de producto compra más cada género
df_female = df[df['Gender'] == 'Female']
df_female.groupby("Product Category")['Total Amount'].sum()
#
# Out:
# Product Category
# Beauty         74830
# Clothing       81275
# Electronics    76735
# Name: Total Amount, dtype: int64

# %%
#Podemos calcular el precio promedio por categoría

df.groupby('Product Category')['Price per Unit'].mean()
# Out:
# Product Category
# Beauty         184.055375
# Clothing       174.287749
# Electronics    181.900585
# Name: Price per Unit, dtype: float64

# %%
#Podemos calcular las unidades vendidas de cada Categoria

df.groupby('Product Category')['Quantity'].sum()
# Out:
# Product Category
# Beauty         771
# Clothing       894
# Electronics    849
# Name: Quantity, dtype: int64
